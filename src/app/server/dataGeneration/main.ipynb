# %%
from mostlyai.sdk import MostlyAI

# initialize client
mostly = MostlyAI(api_key='mostly-af0d9f8123ac841f6a7679ae6855acd96cc253e5938b095adea2cacb62baa11a', base_url='https://app.mostly.ai')

# fetch configuration via API
g = mostly.generators.get('a13e4fde-bb82-40ac-8733-03f3436204fa')
config = g.config()
config

# probe the generator for some samples
mostly.probe('a13e4fde-bb82-40ac-8733-03f3436204fa', size=10)

# use generator to create a synthetic dataset
sd = mostly.generate('a13e4fde-bb82-40ac-8733-03f3436204fa', size=2_000)
sd.data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from mostlyai.sdk import MostlyAI
#       3 # initialize client
#       4 mostly = MostlyAI(api_key='mostly-af0d9f8123ac841f6a7679ae6855acd96cc253e5938b095adea2cacb62baa11a', base_url='https://app.mostly.ai')
#
# ModuleNotFoundError: No module named 'mostlyai'
