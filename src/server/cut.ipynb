# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List, Dict
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "C:\Users\SAGAR\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 8, in <module>
#
#     from pathlib import Path
#
#   File "c:\Python312\Lib\pathlib.py", line 8, in <module>
#
#     import fnmatch
#
#   File "c:\Python312\Lib\fnmatch.py", line 14, in <module>
#
#     import re
#
#   File "c:\Projects\Web\workoutman\src\server\re.py", line 1, in <module>
#
#     import pandas as pd
#
#   File "c:\Python312\Lib\site-packages\pandas\__init__.py", line 32, in <module>
#
#     raise ImportError(
#
# ImportError: Unable to import required dependencies:
#
# numpy: Error importing numpy: you should not try to import numpy from
#
#         its source directory; please exit the numpy source tree, and relaunch
#
#         your python interpreter from there.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Load the data
try:
    df = pd.read_csv('fatLoss.csv')
    print("Dataset loaded successfully!")
except:
    exit()

print("Dataset Overview:")
print(df.head())
print("\nDataset Info:")
print(df.info())
print("\nTarget variable distribution:")

# %%
num_rows = len(df)
num_rows

# %%
df.loc[df['gender'] == 'M', 'BMR'] = (
    88.362
    + (13.397 * df.loc[df['gender'] == 'M', 'current_weight'])
    + (4.799 * df.loc[df['gender'] == 'M', 'height'])
    - (5.677 * df.loc[df['gender'] == 'M', 'age'])
)

df.loc[df['gender'] == 'F', 'BMR'] = (
    447.593
    + (9.247 * df.loc[df['gender'] == 'F', 'current_weight'])
    + (3.098 * df.loc[df['gender'] == 'F', 'height'])
    - (4.330 * df.loc[df['gender'] == 'F', 'age'])
)

df['BMR'].head()

# %%
# def calculate_baseline_fat_loss(
#     age:)
