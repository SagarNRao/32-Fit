# %%
# Example prediction with multiple exercises
example_input = {
    'age': 32,
    'gender': 'M',
    'exercises': [
        {'exercise_name': 'Barbell Bench Press', 'target_muscle_group': 'Chest', 'sets': 4, 'reps': 10, 'weight': 80, 'exercise_category': 'Compound'},
        {'exercise_name': 'Barbell Rows', 'target_muscle_group': 'Back', 'sets': 4, 'reps': 8, 'weight': 70, 'exercise_category': 'Compound'}
    ],
    'frequency': 3,
    'protein': 150,
    'calories': 2800,
    'sleep': 7.5,
    'experience': 'Intermediate',
    'BFP': 20.0,
    'daily_deficit': 350,
    'current_weight': 82.0,
    'height': 178,
    'genetic_advantage': 3,
    'time_months': [3, 6, 9, 12]
}
example_prediction = predict_multi_exercise_body_composition(**example_input)
print('Example Prediction with Multiple Exercises:')
for month, pred in example_prediction.items():
    print(f'Month {month}:')
    if 'error' in pred:
        print(f'  Error: {pred["error"]}')
    else:
        print(f'  Predicted BFP: {pred["bfp"]:.2f}%')
        print(f'  BFP Drop: {pred["bfp_drop"]:.2f}%')
        print(f'  Muscle Mass: {pred["muscle_mass"]:.2f} kg')
        print(f'  Definition Score: {pred["definition"]:.2f}/10')
        print(f'  Weight Loss: {pred["weight_loss"]:.2f} kg')
