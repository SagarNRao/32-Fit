# %%
import pandas as pd

# %%
df = pd.read_csv('mostCommonExercises.csv')
df2 = pd.read_csv('fatLoss.csv')

# %%
merged_df = pd.concat([df, df2.loc[:, ~df2.columns.isin(df.columns)]], axis=1)

merged_df.columns
# Out:
# Index(['exercise_name', 'target_muscle_group', 'type', 'age', 'gender', 'sets',
#        'reps', 'weight', 'frequency', 'protein', 'calories', 'sleep',
#        'experience', 'muscle_size_increase_cm2', 'genetic_advantage',
#        'actual_fat_loss', 'daily_deficit', 'current_weight', 'height'],
#       dtype='object')

# %%
merged_df.to_csv('mostCommonExercises.csv', index=False)

# %%
df2.actual_fat_loss.max()
# Out:
# 23.5
